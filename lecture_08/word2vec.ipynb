# %%
import pandas as pd
import gensim
from sklearn.manifold import TSNE

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import random
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # [Word2Vec Algorithm](https://en.wikipedia.org/wiki/Word2vec)
#
# ### What is it?
# It's a Natural Language Processing [NLP] algorithm that transforms words to vectors.
#
# ### When do I use it?
# When I want to explore semantics of words. For example: find word's oposites, find context word etc.
#
# ### Why should I use it?
# 1] NLP
#
# 2] It's a general idea of mapping elements (eg. strings) onto vectors (and vectors are good to work with). I can use it for recommending next product or a song in playlist.

# %% [markdown]
# # How does it work?
#
# * Word2Vec is actualy shallow Neural Network [NN] (1 hidden layer).
#
# * **Starting point:**
#     * We have N words.
#     * Each word is represented by N-dimensional vector with 1 on index position and 0s elsewhere (one-hot encoding).
#
#
# * We let the NN predict word's naighbours.
#
#
# * We cut out only the guts of the trained NN - scored hidden leayer values for each word.
#
#
# * **End point:**
#     * Each word is represented by only M-dimension vector (M << N), that carries some context information.   **:-)**

# %% [markdown]
# ### Why is it important to have vectors instead of words? Because we have the Algebra!

# %% [markdown]
# ## Word2Vec: one-hot encoding
# <img src="one_hot.png" alt="one_hot" style="width: 600px;"/>

# %% [markdown]
# ## Word2Vec: Word2Vec output
# <img src="w2v_output.png" alt="w2v_output" style="width: 600px;"/>

# %% [markdown]
# ## Approaches:
# * **Skipgram** [SG]
#     * Uses neighbour words as an input to NN and central word as an output.
#
# * **Continuous Bag Of Words** [CBOW]
#     * Uses central word as an input to NN and neighbour words as an output.

# %% [markdown]
# ## Word2Vec: Word neighborhood
# <img src="word_neighbour.png" alt="word_neighbour" style="width: 600px;"/>

# %% [markdown]
# ## Word2Vec: Skipgram method
# <img src="skipgram.png" alt="skipgram" style="width: 600px;"/>

# %% [markdown]
# ## Word2Vec: CBOW method
# <img src="cbow.png" alt="skipgram" style="width: 600px;"/>

# %% [markdown]
# ## Dataset - QUORA

# %%
# Load the dataset
df = pd.read_csv("data/quora.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
# Transfer the dataset into list of lists
def read_questions(row,column_name):
    return gensim.utils.simple_preprocess(str(row[column_name]).encode('utf-8'))
    
documents = []
for index, row in df.iterrows():
    documents.append(read_questions(row,"question1"))
    if row["is_duplicate"] == 0:
        documents.append(read_questions(row,"question2"))

# %%
# document example 
documents[:4]
# Out:
# [['what',
#   'is',
#   'the',
#   'step',
#   'by',
#   'step',
#   'guide',
#   'to',
#   'invest',
#   'in',
#   'share',
#   'market',
#   'in',
#   'india'],
#  ['what',
#   'is',
#   'the',
#   'step',
#   'by',
#   'step',
#   'guide',
#   'to',
#   'invest',
#   'in',
#   'share',
#   'market'],
#  ['what', 'is', 'the', 'story', 'of', 'kohinoor', 'koh', 'noor', 'diamond'],
#  ['what',
#   'would',
#   'happen',
#   'if',
#   'the',
#   'indian',
#   'government',
#   'stole',
#   'the',
#   'kohinoor',
#   'koh',
#   'noor',
#   'diamond',
#   'back']]

# %% [markdown]
# ## Model build

# %%
# Lets train the word2vec model using skipgram/cbow
w2v_model = gensim.models.Word2Vec(size=150, window=10, min_count=5, sg=0, workers=10)
w2v_model.build_vocab(documents) 
w2v_model.train(sentences=documents, total_examples=len(documents), epochs=w2v_model.epochs)
# Out:
# (25175944, 35144510)

# %% [markdown]
# ## Model exploration

# %%
# Model vocabulary
print(f"Our vocabulary hase {len(w2v_model.wv.vocab)} words.")
w2v_model.wv.vocab
# Out:
# Our vocabulary hase 27775 words.
# {'what': <gensim.models.keyedvectors.Vocab at 0x10b28eef0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x112c0e8d0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x112c0e080>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x112c0e0f0>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x112c0e7f0>,
#  'guide': <gensim.models.keyedvectors.Vocab at 0x112c0e1d0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x112c0e240>,
#  'invest': <gensim.models.keyedvectors.Vocab at 0x112c0e400>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x112c0e208>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x112c0e278>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x112c0e438>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x14aa76048>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x14aa76080>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x14aa760b8>,
#  'kohinoor': <gensim.models.keyedvectors.Vocab at 0x14aa760f0>,
#  'koh': <gensim.models.keyedvectors.Vocab at 0x14aa76128>,
#  'noor': <gensim.models.keyedvectors.Vocab at 0x14aa76160>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x14aa76198>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x14aa761d0>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x14aa76208>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x14aa76240>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x14aa76278>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x14aa762b0>,
#  'stole': <gensim.models.keyedvectors.Vocab at 0x14aa762e8>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x14aa76320>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x14aa76358>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x14aa76390>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x14aa763c8>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x14aa76400>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x14aa76438>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x14aa76470>,
#  'connection': <gensim.models.keyedvectors.Vocab at 0x14aa764a8>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x14aa764e0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x14aa76518>,
#  'vpn': <gensim.models.keyedvectors.Vocab at 0x14aa76550>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x14aa76588>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x14aa765c0>,
#  'hacking': <gensim.models.keyedvectors.Vocab at 0x14aa765f8>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x14aa76630>,
#  'dns': <gensim.models.keyedvectors.Vocab at 0x14aa76668>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x14aa766a0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x14aa766d8>,
#  'mentally': <gensim.models.keyedvectors.Vocab at 0x14aa76710>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x14aa76748>,
#  'lonely': <gensim.models.keyedvectors.Vocab at 0x14aa76780>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x14aa767b8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x14aa767f0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x14aa76828>,
#  'remainder': <gensim.models.keyedvectors.Vocab at 0x14aa76860>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x14aa76898>,
#  'math': <gensim.models.keyedvectors.Vocab at 0x14aa768d0>,
#  'divided': <gensim.models.keyedvectors.Vocab at 0x14aa76908>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x14aa76940>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x14aa76978>,
#  'dissolve': <gensim.models.keyedvectors.Vocab at 0x14aa769b0>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x14aa769e8>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x14aa76a20>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x14aa76a58>,
#  'methane': <gensim.models.keyedvectors.Vocab at 0x14aa76a90>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x14aa76ac8>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x14aa76b00>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x14aa76b38>,
#  'oxide': <gensim.models.keyedvectors.Vocab at 0x14aa76b70>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x14aa76ba8>,
#  'survive': <gensim.models.keyedvectors.Vocab at 0x14aa76be0>,
#  'astrology': <gensim.models.keyedvectors.Vocab at 0x14aa76c18>,
#  'capricorn': <gensim.models.keyedvectors.Vocab at 0x14aa76c50>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x14aa76c88>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x14aa76cc0>,
#  'moon': <gensim.models.keyedvectors.Vocab at 0x14aa76cf8>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x14aa76d30>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x14aa76d68>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x14aa76da0>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x14aa76dd8>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x14aa76e10>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x14aa76e48>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x14aa76e80>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x14aa76eb8>,
#  'keeps': <gensim.models.keyedvectors.Vocab at 0x14aa76ef0>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x14aa76f28>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x14aa76f60>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x14aa76f98>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x14aa76fd0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x14aa79048>,
#  'games': <gensim.models.keyedvectors.Vocab at 0x14aa79080>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x14aa790b8>,
#  'geologist': <gensim.models.keyedvectors.Vocab at 0x14aa790f0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x14aa79128>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x14aa79160>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x14aa79198>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x14aa791d0>,
#  'motorola': <gensim.models.keyedvectors.Vocab at 0x14aa79208>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x14aa79240>,
#  'hack': <gensim.models.keyedvectors.Vocab at 0x14aa79278>,
#  'charter': <gensim.models.keyedvectors.Vocab at 0x14aa792b0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x14aa792e8>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x14aa79320>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x14aa79358>,
#  'separation': <gensim.models.keyedvectors.Vocab at 0x14aa79390>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x14aa793c8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x14aa79400>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x14aa79438>,
#  'technicians': <gensim.models.keyedvectors.Vocab at 0x14aa79470>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x14aa794a8>,
#  'durability': <gensim.models.keyedvectors.Vocab at 0x14aa794e0>,
#  'reliability': <gensim.models.keyedvectors.Vocab at 0x14aa79518>,
#  'laptops': <gensim.models.keyedvectors.Vocab at 0x14aa79550>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x14aa79588>,
#  'components': <gensim.models.keyedvectors.Vocab at 0x14aa795c0>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x14aa795f8>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x14aa79630>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x14aa79668>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x14aa796a0>,
#  'physics': <gensim.models.keyedvectors.Vocab at 0x14aa796d8>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x14aa79710>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x14aa79748>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x14aa79780>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x14aa797b8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x14aa797f0>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x14aa79828>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x14aa79860>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x14aa79898>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x14aa798d0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x14aa79908>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x14aa79940>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x14aa79978>,
#  'visa': <gensim.models.keyedvectors.Vocab at 0x14aa799b0>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x14aa799e8>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x14aa79a20>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x14aa79a58>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x14aa79a90>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x14aa79ac8>,
#  'immigration': <gensim.models.keyedvectors.Vocab at 0x14aa79b00>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x14aa79b38>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x14aa79b70>,
#  'trump': <gensim.models.keyedvectors.Vocab at 0x14aa79ba8>,
#  'presidency': <gensim.models.keyedvectors.Vocab at 0x14aa79be0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x14aa79c18>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x14aa79c50>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x14aa79c88>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x14aa79cc0>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x14aa79cf8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x14aa79d30>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x14aa79d68>,
#  'manipulation': <gensim.models.keyedvectors.Vocab at 0x14aa79da0>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x14aa79dd8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x14aa79e10>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x14aa79e48>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x14aa79e80>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x14aa79eb8>,
#  'reject': <gensim.models.keyedvectors.Vocab at 0x14aa79ef0>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x14aa79f28>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x14aa79f60>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x14aa79f98>,
#  'rejecting': <gensim.models.keyedvectors.Vocab at 0x14aa79fd0>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x14aa7d048>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x14aa7d080>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x14aa7d0b8>,
#  'quora': <gensim.models.keyedvectors.Vocab at 0x14aa7d0f0>,
#  'users': <gensim.models.keyedvectors.Vocab at 0x14aa7d128>,
#  'posting': <gensim.models.keyedvectors.Vocab at 0x14aa7d160>,
#  'questions': <gensim.models.keyedvectors.Vocab at 0x14aa7d198>,
#  'readily': <gensim.models.keyedvectors.Vocab at 0x14aa7d1d0>,
#  'answered': <gensim.models.keyedvectors.Vocab at 0x14aa7d208>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x14aa7d240>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x14aa7d278>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x14aa7d2b0>,
#  'marketing': <gensim.models.keyedvectors.Vocab at 0x14aa7d2e8>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x14aa7d320>,
#  'banglore': <gensim.models.keyedvectors.Vocab at 0x14aa7d358>,
#  'institute': <gensim.models.keyedvectors.Vocab at 0x14aa7d390>,
#  'pune': <gensim.models.keyedvectors.Vocab at 0x14aa7d3c8>,
#  'rockets': <gensim.models.keyedvectors.Vocab at 0x14aa7d400>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x14aa7d438>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x14aa7d470>,
#  'causing': <gensim.models.keyedvectors.Vocab at 0x14aa7d4a8>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x14aa7d4e0>,
#  'jealous': <gensim.models.keyedvectors.Vocab at 0x14aa7d518>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x14aa7d550>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x14aa7d588>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x14aa7d5c0>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x14aa7d5f8>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x14aa7d630>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x14aa7d668>,
#  'kv': <gensim.models.keyedvectors.Vocab at 0x14aa7d6a0>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x14aa7d6d8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x14aa7d710>,
#  'conversion': <gensim.models.keyedvectors.Vocab at 0x14aa7d748>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x14aa7d780>,
#  'cc': <gensim.models.keyedvectors.Vocab at 0x14aa7d7b8>,
#  'horsepower': <gensim.models.keyedvectors.Vocab at 0x14aa7d7f0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x14aa7d828>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x14aa7d860>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x14aa7d898>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x14aa7d8d0>,
#  'numbers': <gensim.models.keyedvectors.Vocab at 0x14aa7d908>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x14aa7d940>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x14aa7d978>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x14aa7d9b0>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x14aa7d9e8>,
#  'overlap': <gensim.models.keyedvectors.Vocab at 0x14aa7da20>,
#  'tips': <gensim.models.keyedvectors.Vocab at 0x14aa7da58>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x14aa7da90>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x14aa7dac8>,
#  'interview': <gensim.models.keyedvectors.Vocab at 0x14aa7db00>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x14aa7db38>,
#  'medicines': <gensim.models.keyedvectors.Vocab at 0x14aa7db70>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x14aa7dba8>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x14aa7dbe0>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x14aa7dc18>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x14aa7dc50>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x14aa7dc88>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x14aa7dcc0>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x14aa7dcf8>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x14aa7dd30>,
#  'importance': <gensim.models.keyedvectors.Vocab at 0x14aa7dd68>,
#  'sports': <gensim.models.keyedvectors.Vocab at 0x14aa7dda0>,
#  'contribute': <gensim.models.keyedvectors.Vocab at 0x14aa7ddd8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x14aa7de10>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x14aa7de48>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x14aa7de80>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x14aa7deb8>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x14aa7def0>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x14aa7df28>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x14aa7df60>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x14aa7df98>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x14aa7dfd0>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x14aa80048>,
#  'knowing': <gensim.models.keyedvectors.Vocab at 0x14aa80080>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x14aa800b8>,
#  'cares': <gensim.models.keyedvectors.Vocab at 0x14aa800f0>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x14aa80128>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x14aa80160>,
#  'stuffy': <gensim.models.keyedvectors.Vocab at 0x14aa80198>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x14aa801d0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x14aa80208>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x14aa80240>,
#  'thrones': <gensim.models.keyedvectors.Vocab at 0x14aa80278>,
#  'villain': <gensim.models.keyedvectors.Vocab at 0x14aa802b0>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x14aa802e8>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x14aa80320>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x14aa80358>,
#  'mercy': <gensim.models.keyedvectors.Vocab at 0x14aa80390>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x14aa803c8>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x14aa80400>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x14aa80438>,
#  'blacklist': <gensim.models.keyedvectors.Vocab at 0x14aa80470>,
#  'employment': <gensim.models.keyedvectors.Vocab at 0x14aa804a8>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x14aa804e0>,
#  'citizens': <gensim.models.keyedvectors.Vocab at 0x14aa80518>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x14aa80550>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x14aa80588>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x14aa805c0>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x14aa805f8>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x14aa80630>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x14aa80668>,
#  'molecules': <gensim.models.keyedvectors.Vocab at 0x14aa806a0>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x14aa806d8>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x14aa80710>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x14aa80748>,
#  'spain': <gensim.models.keyedvectors.Vocab at 0x14aa80780>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x14aa807b8>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x14aa807f0>,
#  'obama': <gensim.models.keyedvectors.Vocab at 0x14aa80828>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x14aa80860>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x14aa80898>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x14aa808d0>,
#  'guns': <gensim.models.keyedvectors.Vocab at 0x14aa80908>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x14aa80940>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x14aa80978>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x14aa809b0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x14aa809e8>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x14aa80a20>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x14aa80a58>,
#  'initiative': <gensim.models.keyedvectors.Vocab at 0x14aa80a90>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x14aa80ac8>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x14aa80b00>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x14aa80b38>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x14aa80b70>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x14aa80ba8>,
#  'skills': <gensim.models.keyedvectors.Vocab at 0x14aa80be0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x14aa80c18>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x14aa80c50>,
#  'entrepreneur': <gensim.models.keyedvectors.Vocab at 0x14aa80c88>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x14aa80cc0>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x14aa80cf8>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x14aa80d30>,
#  'billionaire': <gensim.models.keyedvectors.Vocab at 0x14aa80d68>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x14aa80da0>,
#  'asks': <gensim.models.keyedvectors.Vocab at 0x14aa80dd8>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x14aa80e10>,
#  'boyfriend': <gensim.models.keyedvectors.Vocab at 0x14aa80e48>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x14aa80e80>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x14aa80eb8>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x14aa80ef0>,
#  'reply': <gensim.models.keyedvectors.Vocab at 0x14aa80f28>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x14aa80f60>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x14aa80f98>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x14aa80fd0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x14aa82048>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x14aa82080>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x14aa820b8>,
#  'feelings': <gensim.models.keyedvectors.Vocab at 0x14aa820f0>,
#  'wished': <gensim.models.keyedvectors.Vocab at 0x14aa82128>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x14aa82160>,
#  'disconnected': <gensim.models.keyedvectors.Vocab at 0x14aa82198>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x14aa821d0>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x14aa82208>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x14aa82240>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x14aa82278>,
#  'upsc': <gensim.models.keyedvectors.Vocab at 0x14aa822b0>,
#  'stall': <gensim.models.keyedvectors.Vocab at 0x14aa822e8>,
#  'wings': <gensim.models.keyedvectors.Vocab at 0x14aa82320>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x14aa82358>,
#  'swept': <gensim.models.keyedvectors.Vocab at 0x14aa82390>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x14aa823c8>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x14aa82400>,
#  'variable': <gensim.models.keyedvectors.Vocab at 0x14aa82438>,
#  'sweep': <gensim.models.keyedvectors.Vocab at 0x14aa82470>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x14aa824a8>,
#  'slavs': <gensim.models.keyedvectors.Vocab at 0x14aa824e0>,
#  'squat': <gensim.models.keyedvectors.Vocab at 0x14aa82518>,
#  'squats': <gensim.models.keyedvectors.Vocab at 0x14aa82550>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x14aa82588>,
#  'thicker': <gensim.models.keyedvectors.Vocab at 0x14aa825c0>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x14aa825f8>,
#  'cognizant': <gensim.models.keyedvectors.Vocab at 0x14aa82630>,
#  'confirmation': <gensim.models.keyedvectors.Vocab at 0x14aa82668>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x14aa826a0>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x14aa826d8>,
#  'trading': <gensim.models.keyedvectors.Vocab at 0x14aa82710>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x14aa82748>,
#  'rebel': <gensim.models.keyedvectors.Vocab at 0x14aa82780>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x14aa827b8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x14aa827f0>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x14aa82828>,
#  'bored': <gensim.models.keyedvectors.Vocab at 0x14aa82860>,
#  'universities': <gensim.models.keyedvectors.Vocab at 0x14aa82898>,
#  'recruit': <gensim.models.keyedvectors.Vocab at 0x14aa828d0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x14aa82908>,
#  'grads': <gensim.models.keyedvectors.Vocab at 0x14aa82940>,
#  'majors': <gensim.models.keyedvectors.Vocab at 0x14aa82978>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x14aa829b0>,
#  'foods': <gensim.models.keyedvectors.Vocab at 0x14aa829e8>,
#  'quickest': <gensim.models.keyedvectors.Vocab at 0x14aa82a20>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x14aa82a58>,
#  'followers': <gensim.models.keyedvectors.Vocab at 0x14aa82a90>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x14aa82ac8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x14aa82b00>,
#  'darth': <gensim.models.keyedvectors.Vocab at 0x14aa82b38>,
#  'vader': <gensim.models.keyedvectors.Vocab at 0x14aa82b70>,
#  'fought': <gensim.models.keyedvectors.Vocab at 0x14aa82ba8>,
#  'maul': <gensim.models.keyedvectors.Vocab at 0x14aa82be0>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x14aa82c18>,
#  'wars': <gensim.models.keyedvectors.Vocab at 0x14aa82c50>,
#  'legends': <gensim.models.keyedvectors.Vocab at 0x14aa82c88>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x14aa82cc0>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x14aa82cf8>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x14aa82d30>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x14aa82d68>,
#  'descriptions': <gensim.models.keyedvectors.Vocab at 0x14aa82da0>,
#  'stages': <gensim.models.keyedvectors.Vocab at 0x14aa82dd8>,
#  'breaking': <gensim.models.keyedvectors.Vocab at 0x14aa82e10>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x14aa82e48>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x14aa82e80>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x14aa82eb8>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x14aa82ef0>,
#  'emotionally': <gensim.models.keyedvectors.Vocab at 0x14aa82f28>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x14aa82f60>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x14aa82f98>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x14aa82fd0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x14aa85048>,
#  'affected': <gensim.models.keyedvectors.Vocab at 0x14aa85080>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x14aa850b8>,
#  'breakup': <gensim.models.keyedvectors.Vocab at 0x14aa850f0>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x14aa85128>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x14aa85160>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x14aa85198>,
#  'crude': <gensim.models.keyedvectors.Vocab at 0x14aa851d0>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x14aa85208>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x14aa85240>,
#  'launcher': <gensim.models.keyedvectors.Vocab at 0x14aa85278>,
#  'rbi': <gensim.models.keyedvectors.Vocab at 0x14aa852b0>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x14aa852e8>,
#  'preparation': <gensim.models.keyedvectors.Vocab at 0x14aa85320>,
#  'blu': <gensim.models.keyedvectors.Vocab at 0x14aa85358>,
#  'ray': <gensim.models.keyedvectors.Vocab at 0x14aa85390>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x14aa853c8>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x14aa85400>,
#  'dvd': <gensim.models.keyedvectors.Vocab at 0x14aa85438>,
#  'player': <gensim.models.keyedvectors.Vocab at 0x14aa85470>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x14aa854a8>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x14aa854e0>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x14aa85518>,
#  'rotates': <gensim.models.keyedvectors.Vocab at 0x14aa85550>,
#  'memorable': <gensim.models.keyedvectors.Vocab at 0x14aa85588>,
#  've': <gensim.models.keyedvectors.Vocab at 0x14aa855c0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x14aa855f8>,
#  'eaten': <gensim.models.keyedvectors.Vocab at 0x14aa85630>,
#  'gst': <gensim.models.keyedvectors.Vocab at 0x14aa85668>,
#  'affects': <gensim.models.keyedvectors.Vocab at 0x14aa856a0>,
#  'cas': <gensim.models.keyedvectors.Vocab at 0x14aa856d8>,
#  'tax': <gensim.models.keyedvectors.Vocab at 0x14aa85710>,
#  'officers': <gensim.models.keyedvectors.Vocab at 0x14aa85748>,
#  'homework': <gensim.models.keyedvectors.Vocab at 0x14aa85780>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x14aa857b8>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x14aa857f0>,
#  'rsi': <gensim.models.keyedvectors.Vocab at 0x14aa85828>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x14aa85860>,
#  'programs': <gensim.models.keyedvectors.Vocab at 0x14aa85898>,
#  're': <gensim.models.keyedvectors.Vocab at 0x14aa858d0>,
#  'senior': <gensim.models.keyedvectors.Vocab at 0x14aa85908>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x14aa85940>,
#  'lying': <gensim.models.keyedvectors.Vocab at 0x14aa85978>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x14aa859b0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x14aa859e8>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x14aa85a20>,
#  'secretly': <gensim.models.keyedvectors.Vocab at 0x14aa85a58>,
#  'attracted': <gensim.models.keyedvectors.Vocab at 0x14aa85a90>,
#  'rap': <gensim.models.keyedvectors.Vocab at 0x14aa85ac8>,
#  'songs': <gensim.models.keyedvectors.Vocab at 0x14aa85b00>,
#  'dance': <gensim.models.keyedvectors.Vocab at 0x14aa85b38>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x14aa85b70>,
#  'logged': <gensim.models.keyedvectors.Vocab at 0x14aa85ba8>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x14aa85be0>,
#  'gmail': <gensim.models.keyedvectors.Vocab at 0x14aa85c18>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x14aa85c50>,
#  'password': <gensim.models.keyedvectors.Vocab at 0x14aa85c88>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x14aa85cc0>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x14aa85cf8>,
#  'recovery': <gensim.models.keyedvectors.Vocab at 0x14aa85d30>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x14aa85d68>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x14aa85da0>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x14aa85dd8>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x14aa85e10>,
#  'ways': <gensim.models.keyedvectors.Vocab at 0x14aa85e48>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x14aa85e80>,
#  'genders': <gensim.models.keyedvectors.Vocab at 0x14aa85eb8>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x14aa85ef0>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x14aa85f28>,
#  'kickass': <gensim.models.keyedvectors.Vocab at 0x14aa85f60>,
#  'torrent': <gensim.models.keyedvectors.Vocab at 0x14aa85f98>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x14aa85fd0>,
#  'registration': <gensim.models.keyedvectors.Vocab at 0x14aa8a048>,
#  'torrents': <gensim.models.keyedvectors.Vocab at 0x14aa8a080>,
#  'trustworthy': <gensim.models.keyedvectors.Vocab at 0x14aa8a0b8>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x14aa8a0f0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x14aa8a128>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x14aa8a160>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x14aa8a198>,
#  'iris': <gensim.models.keyedvectors.Vocab at 0x14aa8a1d0>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x14aa8a208>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x14aa8a240>,
#  'treated': <gensim.models.keyedvectors.Vocab at 0x14aa8a278>,
#  'harry': <gensim.models.keyedvectors.Vocab at 0x14aa8a2b0>,
#  'potter': <gensim.models.keyedvectors.Vocab at 0x14aa8a2e8>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x14aa8a320>,
#  'cursed': <gensim.models.keyedvectors.Vocab at 0x14aa8a358>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x14aa8a390>,
#  'depressed': <gensim.models.keyedvectors.Vocab at 0x14aa8a3c8>,
#  'evening': <gensim.models.keyedvectors.Vocab at 0x14aa8a400>,
#  'european': <gensim.models.keyedvectors.Vocab at 0x14aa8a438>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x14aa8a470>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x14aa8a4a8>,
#  'database': <gensim.models.keyedvectors.Vocab at 0x14aa8a4e0>,
#  'java': <gensim.models.keyedvectors.Vocab at 0x14aa8a518>,
#  'programming': <gensim.models.keyedvectors.Vocab at 0x14aa8a550>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x14aa8a588>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x14aa8a5c0>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x14aa8a5f8>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x14aa8a630>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x14aa8a668>,
#  'lightning': <gensim.models.keyedvectors.Vocab at 0x14aa8a6a0>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x14aa8a6d8>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x14aa8a710>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x14aa8a748>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x14aa8a780>,
#  'privacy': <gensim.models.keyedvectors.Vocab at 0x14aa8a7b8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x14aa8a7f0>,
#  'germany': <gensim.models.keyedvectors.Vocab at 0x14aa8a828>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x14aa8a860>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x14aa8a898>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x14aa8a8d0>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x14aa8a908>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x14aa8a940>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x14aa8a978>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x14aa8a9b0>,
#  'salad': <gensim.models.keyedvectors.Vocab at 0x14aa8a9e8>,
#  'dressing': <gensim.models.keyedvectors.Vocab at 0x14aa8aa20>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x14aa8aa58>,
#  'immunity': <gensim.models.keyedvectors.Vocab at 0x14aa8aa90>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x14aa8aac8>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x14aa8ab00>,
#  'narcissistic': <gensim.models.keyedvectors.Vocab at 0x14aa8ab38>,
#  'personality': <gensim.models.keyedvectors.Vocab at 0x14aa8ab70>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x14aa8aba8>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x14aa8abe0>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x14aa8ac18>,
#  'fluently': <gensim.models.keyedvectors.Vocab at 0x14aa8ac50>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x14aa8ac88>,
#  'quickbooks': <gensim.models.keyedvectors.Vocab at 0x14aa8acc0>,
#  'auto': <gensim.models.keyedvectors.Vocab at 0x14aa8acf8>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x14aa8ad30>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x14aa8ad68>,
#  'recover': <gensim.models.keyedvectors.Vocab at 0x14aa8ada0>,
#  'corrupted': <gensim.models.keyedvectors.Vocab at 0x14aa8add8>,
#  'files': <gensim.models.keyedvectors.Vocab at 0x14aa8ae10>,
#  'richest': <gensim.models.keyedvectors.Vocab at 0x14aa8ae48>,
#  'gambler': <gensim.models.keyedvectors.Vocab at 0x14aa8ae80>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x14aa8aeb8>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x14aa8aef0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x14aa8af28>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x14aa8af60>,
#  'bullet': <gensim.models.keyedvectors.Vocab at 0x14aa8af98>,
#  'backward': <gensim.models.keyedvectors.Vocab at 0x14aa8afd0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x14aa8d048>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x14aa8d080>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x14aa8d0b8>,
#  'backwards': <gensim.models.keyedvectors.Vocab at 0x14aa8d0f0>,
#  'bullets': <gensim.models.keyedvectors.Vocab at 0x14aa8d128>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x14aa8d160>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x14aa8d198>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x14aa8d1d0>,
#  'occurs': <gensim.models.keyedvectors.Vocab at 0x14aa8d208>,
#  'prevent': <gensim.models.keyedvectors.Vocab at 0x14aa8d240>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x14aa8d278>,
#  'cancer': <gensim.models.keyedvectors.Vocab at 0x14aa8d2b0>,
#  'log': <gensim.models.keyedvectors.Vocab at 0x14aa8d2e8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x14aa8d320>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x14aa8d358>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x14aa8d390>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x14aa8d3c8>,
#  'ip': <gensim.models.keyedvectors.Vocab at 0x14aa8d400>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x14aa8d438>,
#  'device': <gensim.models.keyedvectors.Vocab at 0x14aa8d470>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x14aa8d4a8>,
#  'excluding': <gensim.models.keyedvectors.Vocab at 0x14aa8d4e0>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x14aa8d518>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x14aa8d550>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x14aa8d588>,
#  'bjp': <gensim.models.keyedvectors.Vocab at 0x14aa8d5c0>,
#  'strip': <gensim.models.keyedvectors.Vocab at 0x14aa8d5f8>,
#  'muslims': <gensim.models.keyedvectors.Vocab at 0x14aa8d630>,
#  'christians': <gensim.models.keyedvectors.Vocab at 0x14aa8d668>,
#  'citizenship': <gensim.models.keyedvectors.Vocab at 0x14aa8d6a0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x14aa8d6d8>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x14aa8d710>,
#  'boats': <gensim.models.keyedvectors.Vocab at 0x14aa8d748>,
#  'rohingya': <gensim.models.keyedvectors.Vocab at 0x14aa8d780>,
#  'burma': <gensim.models.keyedvectors.Vocab at 0x14aa8d7b8>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x14aa8d7f0>,
#  'deport': <gensim.models.keyedvectors.Vocab at 0x14aa8d828>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x14aa8d860>,
#  'bangladeshis': <gensim.models.keyedvectors.Vocab at 0x14aa8d898>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x14aa8d8d0>,
#  'etiquette': <gensim.models.keyedvectors.Vocab at 0x14aa8d908>,
#  'wishing': <gensim.models.keyedvectors.Vocab at 0x14aa8d940>,
#  'jehovah': <gensim.models.keyedvectors.Vocab at 0x14aa8d978>,
#  'witness': <gensim.models.keyedvectors.Vocab at 0x14aa8d9b0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x14aa8d9e8>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x14aa8da20>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x14aa8da58>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x14aa8da90>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x14aa8dac8>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x14aa8db00>,
#  'commercial': <gensim.models.keyedvectors.Vocab at 0x14aa8db38>,
#  'fm': <gensim.models.keyedvectors.Vocab at 0x14aa8db70>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x14aa8dba8>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x14aa8dbe0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x14aa8dc18>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x14aa8dc50>,
#  'clip': <gensim.models.keyedvectors.Vocab at 0x14aa8dc88>,
#  'hd': <gensim.models.keyedvectors.Vocab at 0x14aa8dcc0>,
#  'zealand': <gensim.models.keyedvectors.Vocab at 0x14aa8dcf8>,
#  'swiss': <gensim.models.keyedvectors.Vocab at 0x14aa8dd30>,
#  'despise': <gensim.models.keyedvectors.Vocab at 0x14aa8dd68>,
#  'asians': <gensim.models.keyedvectors.Vocab at 0x14aa8dda0>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x14aa8ddd8>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x14aa8de10>,
#  'sales': <gensim.models.keyedvectors.Vocab at 0x14aa8de48>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x14aa8de80>,
#  'salary': <gensim.models.keyedvectors.Vocab at 0x14aa8deb8>,
#  'income': <gensim.models.keyedvectors.Vocab at 0x14aa8def0>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x14aa8df28>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x14aa8df60>,
#  'biotechnology': <gensim.models.keyedvectors.Vocab at 0x14aa8df98>,
#  'height': <gensim.models.keyedvectors.Vocab at 0x14aa8dfd0>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x14aa90048>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x14aa90080>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x14aa900b8>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x14aa900f0>,
#  'cambodia': <gensim.models.keyedvectors.Vocab at 0x14aa90128>,
#  'earthquake': <gensim.models.keyedvectors.Vocab at 0x14aa90160>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x14aa90198>,
#  'kamchatca': <gensim.models.keyedvectors.Vocab at 0x14aa901d0>,
#  'earthquakes': <gensim.models.keyedvectors.Vocab at 0x14aa90208>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x14aa90240>,
#  'fairness': <gensim.models.keyedvectors.Vocab at 0x14aa90278>,
#  'honest': <gensim.models.keyedvectors.Vocab at 0x14aa902b0>,
#  'sincere': <gensim.models.keyedvectors.Vocab at 0x14aa902e8>,
#  'gaming': <gensim.models.keyedvectors.Vocab at 0x14aa90320>,
#  'laptop': <gensim.models.keyedvectors.Vocab at 0x14aa90358>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x14aa90390>,
#  'inr': <gensim.models.keyedvectors.Vocab at 0x14aa903c8>,
#  'warrior': <gensim.models.keyedvectors.Vocab at 0x14aa90400>,
#  'proving': <gensim.models.keyedvectors.Vocab at 0x14aa90438>,
#  'grounds': <gensim.models.keyedvectors.Vocab at 0x14aa90470>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x14aa904a8>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x14aa904e0>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x14aa90518>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x14aa90550>,
#  'chemistry': <gensim.models.keyedvectors.Vocab at 0x14aa90588>,
#  'cbse': <gensim.models.keyedvectors.Vocab at 0x14aa905c0>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x14aa905f8>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x14aa90630>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x14aa90668>,
#  'kurukshetra': <gensim.models.keyedvectors.Vocab at 0x14aa906a0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x14aa906d8>,
#  'nitk': <gensim.models.keyedvectors.Vocab at 0x14aa90710>,
#  'surathkal': <gensim.models.keyedvectors.Vocab at 0x14aa90748>,
#  'karnataka': <gensim.models.keyedvectors.Vocab at 0x14aa90780>,
#  'graduating': <gensim.models.keyedvectors.Vocab at 0x14aa907b8>,
#  'batch': <gensim.models.keyedvectors.Vocab at 0x14aa907f0>,
#  'lessons': <gensim.models.keyedvectors.Vocab at 0x14aa90828>,
#  'juniors': <gensim.models.keyedvectors.Vocab at 0x14aa90860>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x14aa90898>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x14aa908d0>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x14aa90908>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x14aa90940>,
#  'nightmare': <gensim.models.keyedvectors.Vocab at 0x14aa90978>,
#  'abstract': <gensim.models.keyedvectors.Vocab at 0x14aa909b0>,
#  'painting': <gensim.models.keyedvectors.Vocab at 0x14aa909e8>,
#  'influences': <gensim.models.keyedvectors.Vocab at 0x14aa90a20>,
#  'printing': <gensim.models.keyedvectors.Vocab at 0x14aa90a58>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x14aa90a90>,
#  'attend': <gensim.models.keyedvectors.Vocab at 0x14aa90ac8>,
#  'caltech': <gensim.models.keyedvectors.Vocab at 0x14aa90b00>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x14aa90b38>,
#  'notable': <gensim.models.keyedvectors.Vocab at 0x14aa90b70>,
#  'folks': <gensim.models.keyedvectors.Vocab at 0x14aa90ba8>,
#  'attended': <gensim.models.keyedvectors.Vocab at 0x14aa90be0>,
#  'horcrux': <gensim.models.keyedvectors.Vocab at 0x14aa90c18>,
#  'associate': <gensim.models.keyedvectors.Vocab at 0x14aa90c50>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x14aa90c88>,
#  'manager': <gensim.models.keyedvectors.Vocab at 0x14aa90cc0>,
#  'apm': <gensim.models.keyedvectors.Vocab at 0x14aa90cf8>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x14aa90d30>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x14aa90d68>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x14aa90da0>,
#  'rewarding': <gensim.models.keyedvectors.Vocab at 0x14aa90dd8>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x14aa90e10>,
#  'requirement': <gensim.models.keyedvectors.Vocab at 0x14aa90e48>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x14aa90e80>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x14aa90eb8>,
#  'software': <gensim.models.keyedvectors.Vocab at 0x14aa90ef0>,
#  'skype': <gensim.models.keyedvectors.Vocab at 0x14aa90f28>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x14aa90f60>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x14aa90f98>,
#  'android': <gensim.models.keyedvectors.Vocab at 0x14aa90fd0>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x14aa95048>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x14aa95080>,
#  'pakistan': <gensim.models.keyedvectors.Vocab at 0x14aa950b8>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x14aa950f0>,
#  'uri': <gensim.models.keyedvectors.Vocab at 0x14aa95128>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x14aa95160>,
#  'ronald': <gensim.models.keyedvectors.Vocab at 0x14aa95198>,
#  'reagan': <gensim.models.keyedvectors.Vocab at 0x14aa951d0>,
#  'speech': <gensim.models.keyedvectors.Vocab at 0x14aa95208>,
#  'react': <gensim.models.keyedvectors.Vocab at 0x14aa95240>,
#  'strategies': <gensim.models.keyedvectors.Vocab at 0x14aa95278>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x14aa952b0>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x14aa952e8>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x14aa95320>,
#  'defeated': <gensim.models.keyedvectors.Vocab at 0x14aa95358>,
#  'forces': <gensim.models.keyedvectors.Vocab at 0x14aa95390>,
#  'gettysburg': <gensim.models.keyedvectors.Vocab at 0x14aa953c8>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x14aa95400>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x14aa95438>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x14aa95470>,
#  'novels': <gensim.models.keyedvectors.Vocab at 0x14aa954a8>,
#  'forgot': <gensim.models.keyedvectors.Vocab at 0x14aa954e0>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x14aa95518>,
#  'demonetisation': <gensim.models.keyedvectors.Vocab at 0x14aa95550>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x14aa95588>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x14aa955c0>,
#  'gdp': <gensim.models.keyedvectors.Vocab at 0x14aa955f8>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x14aa95630>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x14aa95668>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x14aa956a0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x14aa956d8>,
#  'whatsapp': <gensim.models.keyedvectors.Vocab at 0x14aa95710>,
#  'hacked': <gensim.models.keyedvectors.Vocab at 0x14aa95748>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x14aa95780>,
#  'pity': <gensim.models.keyedvectors.Vocab at 0x14aa957b8>,
#  'competitive': <gensim.models.keyedvectors.Vocab at 0x14aa957f0>,
#  'hiring': <gensim.models.keyedvectors.Vocab at 0x14aa95828>,
#  'republic': <gensim.models.keyedvectors.Vocab at 0x14aa95860>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x14aa95898>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x14aa958d0>,
#  'spam': <gensim.models.keyedvectors.Vocab at 0x14aa95908>,
#  'ranking': <gensim.models.keyedvectors.Vocab at 0x14aa95940>,
#  'adjustment': <gensim.models.keyedvectors.Vocab at 0x14aa95978>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x14aa959b0>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x14aa959e8>,
#  'traffic': <gensim.models.keyedvectors.Vocab at 0x14aa95a20>,
#  'organic': <gensim.models.keyedvectors.Vocab at 0x14aa95a58>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x14aa95a90>,
#  'rankings': <gensim.models.keyedvectors.Vocab at 0x14aa95ac8>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x14aa95b00>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x14aa95b38>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x14aa95b70>,
#  'subtitles': <gensim.models.keyedvectors.Vocab at 0x14aa95ba8>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x14aa95be0>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x14aa95c18>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x14aa95c50>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x14aa95c88>,
#  'obtain': <gensim.models.keyedvectors.Vocab at 0x14aa95cc0>,
#  'instant': <gensim.models.keyedvectors.Vocab at 0x14aa95cf8>,
#  'ulcer': <gensim.models.keyedvectors.Vocab at 0x14aa95d30>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x14aa95d68>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x14aa95da0>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x14aa95dd8>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x14aa95e10>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x14aa95e48>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x14aa95e80>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x14aa95eb8>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x14aa95ef0>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x14aa95f28>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x14aa95f60>,
#  'materialistic': <gensim.models.keyedvectors.Vocab at 0x14aa95f98>,
#  'cry': <gensim.models.keyedvectors.Vocab at 0x14aa95fd0>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x14aa98048>,
#  'tongues': <gensim.models.keyedvectors.Vocab at 0x14aa98080>,
#  'pictures': <gensim.models.keyedvectors.Vocab at 0x14aa980b8>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x14aa980f0>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x14aa98128>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x14aa98160>,
#  'boyfriends': <gensim.models.keyedvectors.Vocab at 0x14aa98198>,
#  'naked': <gensim.models.keyedvectors.Vocab at 0x14aa981d0>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x14aa98208>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x14aa98240>,
#  'depressing': <gensim.models.keyedvectors.Vocab at 0x14aa98278>,
#  'winston': <gensim.models.keyedvectors.Vocab at 0x14aa982b0>,
#  'julia': <gensim.models.keyedvectors.Vocab at 0x14aa982e8>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x14aa98320>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x14aa98358>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x14aa98390>,
#  'blowing': <gensim.models.keyedvectors.Vocab at 0x14aa983c8>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x14aa98400>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x14aa98438>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x14aa98470>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x14aa984a8>,
#  'technologies': <gensim.models.keyedvectors.Vocab at 0x14aa984e0>,
#  'toothbrush': <gensim.models.keyedvectors.Vocab at 0x14aa98518>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x14aa98550>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x14aa98588>,
#  'applying': <gensim.models.keyedvectors.Vocab at 0x14aa985c0>,
#  'toothpaste': <gensim.models.keyedvectors.Vocab at 0x14aa985f8>,
#  'cheapest': <gensim.models.keyedvectors.Vocab at 0x14aa98630>,
#  'marked': <gensim.models.keyedvectors.Vocab at 0x14aa98668>,
#  'needing': <gensim.models.keyedvectors.Vocab at 0x14aa986a0>,
#  'imrovement': <gensim.models.keyedvectors.Vocab at 0x14aa986d8>,
#  'neutral': <gensim.models.keyedvectors.Vocab at 0x14aa98710>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x14aa98748>,
#  'buffer': <gensim.models.keyedvectors.Vocab at 0x14aa98780>,
#  'declared': <gensim.models.keyedvectors.Vocab at 0x14aa987b8>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x14aa987f0>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x14aa98828>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x14aa98860>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x14aa98898>,
#  'mineral': <gensim.models.keyedvectors.Vocab at 0x14aa988d0>,
#  'holds': <gensim.models.keyedvectors.Vocab at 0x14aa98908>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x14aa98940>,
#  'electrical': <gensim.models.keyedvectors.Vocab at 0x14aa98978>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x14aa989b0>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x14aa989e8>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x14aa98a20>,
#  'universe': <gensim.models.keyedvectors.Vocab at 0x14aa98a58>,
#  'alternative': <gensim.models.keyedvectors.Vocab at 0x14aa98a90>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x14aa98ac8>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x14aa98b00>,
#  'sample': <gensim.models.keyedvectors.Vocab at 0x14aa98b38>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x14aa98b70>,
#  'imbalance': <gensim.models.keyedvectors.Vocab at 0x14aa98ba8>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x14aa98be0>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x14aa98c18>,
#  'sanctions': <gensim.models.keyedvectors.Vocab at 0x14aa98c50>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x14aa98c88>,
#  'mohammad': <gensim.models.keyedvectors.Vocab at 0x14aa98cc0>,
#  'jem': <gensim.models.keyedvectors.Vocab at 0x14aa98cf8>,
#  'chief': <gensim.models.keyedvectors.Vocab at 0x14aa98d30>,
#  'masood': <gensim.models.keyedvectors.Vocab at 0x14aa98d68>,
#  'azhar': <gensim.models.keyedvectors.Vocab at 0x14aa98da0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x14aa98dd8>,
#  'budget': <gensim.models.keyedvectors.Vocab at 0x14aa98e10>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x14aa98e48>,
#  'excessive': <gensim.models.keyedvectors.Vocab at 0x14aa98e80>,
#  'amounts': <gensim.models.keyedvectors.Vocab at 0x14aa98eb8>,
#  'vitamin': <gensim.models.keyedvectors.Vocab at 0x14aa98ef0>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x14aa98f28>,
#  'miscarriage': <gensim.models.keyedvectors.Vocab at 0x14aa98f60>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x14aa98f98>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x14aa98fd0>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x14aa9b048>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x14aa9b080>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x14aa9b0b8>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x14aa9b0f0>,
#  'recruitment': <gensim.models.keyedvectors.Vocab at 0x14aa9b128>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x14aa9b160>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x14aa9b198>,
#  'mantras': <gensim.models.keyedvectors.Vocab at 0x14aa9b1d0>,
#  'mantra': <gensim.models.keyedvectors.Vocab at 0x14aa9b208>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x14aa9b240>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x14aa9b278>,
#  'talks': <gensim.models.keyedvectors.Vocab at 0x14aa9b2b0>,
#  'successful': <gensim.models.keyedvectors.Vocab at 0x14aa9b2e8>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x14aa9b320>,
#  'nicmar': <gensim.models.keyedvectors.Vocab at 0x14aa9b358>,
#  'register': <gensim.models.keyedvectors.Vocab at 0x14aa9b390>,
#  'domain': <gensim.models.keyedvectors.Vocab at 0x14aa9b3c8>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x14aa9b400>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x14aa9b438>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x14aa9b470>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x14aa9b4a8>,
#  'strongest': <gensim.models.keyedvectors.Vocab at 0x14aa9b4e0>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x14aa9b518>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x14aa9b550>,
#  'compression': <gensim.models.keyedvectors.Vocab at 0x14aa9b588>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x14aa9b5c0>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x14aa9b5f8>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x14aa9b630>,
#  'selfish': <gensim.models.keyedvectors.Vocab at 0x14aa9b668>,
#  'evil': <gensim.models.keyedvectors.Vocab at 0x14aa9b6a0>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x14aa9b6d8>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x14aa9b710>,
#  'cells': <gensim.models.keyedvectors.Vocab at 0x14aa9b748>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x14aa9b780>,
#  'bald': <gensim.models.keyedvectors.Vocab at 0x14aa9b7b8>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x14aa9b7f0>,
#  'shave': <gensim.models.keyedvectors.Vocab at 0x14aa9b828>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x14aa9b860>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x14aa9b898>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x14aa9b8d0>,
#  'loose': <gensim.models.keyedvectors.Vocab at 0x14aa9b908>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x14aa9b940>,
#  'retirement': <gensim.models.keyedvectors.Vocab at 0x14aa9b978>,
#  'stance': <gensim.models.keyedvectors.Vocab at 0x14aa9b9b0>,
#  'possession': <gensim.models.keyedvectors.Vocab at 0x14aa9b9e8>,
#  'weapons': <gensim.models.keyedvectors.Vocab at 0x14aa9ba20>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x14aa9ba58>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x14aa9ba90>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x14aa9bac8>,
#  'korea': <gensim.models.keyedvectors.Vocab at 0x14aa9bb00>,
#  'websites': <gensim.models.keyedvectors.Vocab at 0x14aa9bb38>,
#  'escorts': <gensim.models.keyedvectors.Vocab at 0x14aa9bb70>,
#  'escort': <gensim.models.keyedvectors.Vocab at 0x14aa9bba8>,
#  'polo': <gensim.models.keyedvectors.Vocab at 0x14aa9bbe0>,
#  'diesel': <gensim.models.keyedvectors.Vocab at 0x14aa9bc18>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x14aa9bc50>,
#  'petrol': <gensim.models.keyedvectors.Vocab at 0x14aa9bc88>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x14aa9bcc0>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x14aa9bcf8>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x14aa9bd30>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x14aa9bd68>,
#  'morgan': <gensim.models.keyedvectors.Vocab at 0x14aa9bda0>,
#  'freeman': <gensim.models.keyedvectors.Vocab at 0x14aa9bdd8>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x14aa9be10>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x14aa9be48>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x14aa9be80>,
#  'racism': <gensim.models.keyedvectors.Vocab at 0x14aa9beb8>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x14aa9bef0>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x14aa9bf28>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x14aa9bf60>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x14aa9bf98>,
#  'options': <gensim.models.keyedvectors.Vocab at 0x14aa9bfd0>,
#  'rsus': <gensim.models.keyedvectors.Vocab at 0x14aa9e048>,
#  'uber': <gensim.models.keyedvectors.Vocab at 0x14aa9e080>,
#  'reviews': <gensim.models.keyedvectors.Vocab at 0x14aa9e0b8>,
#  'distribute': <gensim.models.keyedvectors.Vocab at 0x14aa9e0f0>,
#  'identical': <gensim.models.keyedvectors.Vocab at 0x14aa9e128>,
#  'pencils': <gensim.models.keyedvectors.Vocab at 0x14aa9e160>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x14aa9e198>,
#  'pencil': <gensim.models.keyedvectors.Vocab at 0x14aa9e1d0>,
#  'apples': <gensim.models.keyedvectors.Vocab at 0x14aa9e208>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x14aa9e240>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x14aa9e278>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x14aa9e2b0>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x14aa9e2e8>,
#  'hire': <gensim.models.keyedvectors.Vocab at 0x14aa9e320>,
#  'jerry': <gensim.models.keyedvectors.Vocab at 0x14aa9e358>,
#  'seinfeld': <gensim.models.keyedvectors.Vocab at 0x14aa9e390>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x14aa9e3c8>,
#  'tape': <gensim.models.keyedvectors.Vocab at 0x14aa9e400>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x14aa9e438>,
#  'presentation': <gensim.models.keyedvectors.Vocab at 0x14aa9e470>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x14aa9e4a8>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x14aa9e4e0>,
#  'rabies': <gensim.models.keyedvectors.Vocab at 0x14aa9e518>,
#  'vaccine': <gensim.models.keyedvectors.Vocab at 0x14aa9e550>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x14aa9e588>,
#  'bite': <gensim.models.keyedvectors.Vocab at 0x14aa9e5c0>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x14aa9e5f8>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x14aa9e630>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x14aa9e668>,
#  'britain': <gensim.models.keyedvectors.Vocab at 0x14aa9e6a0>,
#  'ruled': <gensim.models.keyedvectors.Vocab at 0x14aa9e6d8>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x14aa9e710>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x14aa9e748>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x14aa9e780>,
#  'relocation': <gensim.models.keyedvectors.Vocab at 0x14aa9e7b8>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x14aa9e7f0>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x14aa9e828>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x14aa9e860>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x14aa9e898>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x14aa9e8d0>,
#  'keys': <gensim.models.keyedvectors.Vocab at 0x14aa9e908>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x14aa9e940>,
#  'virginity': <gensim.models.keyedvectors.Vocab at 0x14aa9e978>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x14aa9e9b0>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x14aa9e9e8>,
#  'snoke': <gensim.models.keyedvectors.Vocab at 0x14aa9ea20>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x14aa9ea58>,
#  'emperor': <gensim.models.keyedvectors.Vocab at 0x14aa9ea90>,
#  'palpatine': <gensim.models.keyedvectors.Vocab at 0x14aa9eac8>,
#  'monetize': <gensim.models.keyedvectors.Vocab at 0x14aa9eb00>,
#  'videos': <gensim.models.keyedvectors.Vocab at 0x14aa9eb38>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x14aa9eb70>,
#  'copyright': <gensim.models.keyedvectors.Vocab at 0x14aa9eba8>,
#  'chances': <gensim.models.keyedvectors.Vocab at 0x14aa9ebe0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x14aa9ec18>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x14aa9ec50>,
#  'canon': <gensim.models.keyedvectors.Vocab at 0x14aa9ec88>,
#  'leica': <gensim.models.keyedvectors.Vocab at 0x14aa9ecc0>,
#  'lux': <gensim.models.keyedvectors.Vocab at 0x14aa9ecf8>,
#  'tripod': <gensim.models.keyedvectors.Vocab at 0x14aa9ed30>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x14aa9ed68>,
#  'moderation': <gensim.models.keyedvectors.Vocab at 0x14aa9eda0>,
#  'nobody': <gensim.models.keyedvectors.Vocab at 0x14aa9edd8>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x14aa9ee10>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x14aa9ee48>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x14aa9ee80>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x14aa9eeb8>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x14aa9eef0>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x14aa9ef28>,
#  'deduction': <gensim.models.keyedvectors.Vocab at 0x14aa9ef60>,
#  'pls': <gensim.models.keyedvectors.Vocab at 0x14aa9ef98>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x14aa9efd0>,
#  'monthly': <gensim.models.keyedvectors.Vocab at 0x14aaa3048>,
#  'expenses': <gensim.models.keyedvectors.Vocab at 0x14aaa3080>,
#  'saving': <gensim.models.keyedvectors.Vocab at 0x14aaa30b8>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x14aaa30f0>,
#  'norway': <gensim.models.keyedvectors.Vocab at 0x14aaa3128>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x14aaa3160>,
#  'mortgage': <gensim.models.keyedvectors.Vocab at 0x14aaa3198>,
#  'sell': <gensim.models.keyedvectors.Vocab at 0x14aaa31d0>,
#  'apartment': <gensim.models.keyedvectors.Vocab at 0x14aaa3208>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x14aaa3240>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x14aaa3278>,
#  'kingdom': <gensim.models.keyedvectors.Vocab at 0x14aaa32b0>,
#  'americans': <gensim.models.keyedvectors.Vocab at 0x14aaa32e8>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x14aaa3320>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x14aaa3358>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x14aaa3390>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x14aaa33c8>,
#  'skrill': <gensim.models.keyedvectors.Vocab at 0x14aaa3400>,
#  'paypal': <gensim.models.keyedvectors.Vocab at 0x14aaa3438>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x14aaa3470>,
#  'withdraw': <gensim.models.keyedvectors.Vocab at 0x14aaa34a8>,
#  'earphone': <gensim.models.keyedvectors.Vocab at 0x14aaa34e0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x14aaa3518>,
#  'bass': <gensim.models.keyedvectors.Vocab at 0x14aaa3550>,
#  'eligible': <gensim.models.keyedvectors.Vocab at 0x14aaa3588>,
#  'yojana': <gensim.models.keyedvectors.Vocab at 0x14aaa35c0>,
#  'employee': <gensim.models.keyedvectors.Vocab at 0x14aaa35f8>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x14aaa3630>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x14aaa3668>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x14aaa36a0>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x14aaa36d8>,
#  'abusing': <gensim.models.keyedvectors.Vocab at 0x14aaa3710>,
#  'abusive': <gensim.models.keyedvectors.Vocab at 0x14aaa3748>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x14aaa3780>,
#  'ex': <gensim.models.keyedvectors.Vocab at 0x14aaa37b8>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x14aaa37f0>,
#  'coworkers': <gensim.models.keyedvectors.Vocab at 0x14aaa3828>,
#  'bosses': <gensim.models.keyedvectors.Vocab at 0x14aaa3860>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x14aaa3898>,
#  'gross': <gensim.models.keyedvectors.Vocab at 0x14aaa38d0>,
#  'ctc': <gensim.models.keyedvectors.Vocab at 0x14aaa3908>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x14aaa3940>,
#  'weekly': <gensim.models.keyedvectors.Vocab at 0x14aaa3978>,
#  'paycheck': <gensim.models.keyedvectors.Vocab at 0x14aaa39b0>,
#  'yearly': <gensim.models.keyedvectors.Vocab at 0x14aaa39e8>,
#  'employer': <gensim.models.keyedvectors.Vocab at 0x14aaa3a20>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x14aaa3a58>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x14aaa3a90>,
#  'towns': <gensim.models.keyedvectors.Vocab at 0x14aaa3ac8>,
#  'kerala': <gensim.models.keyedvectors.Vocab at 0x14aaa3b00>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x14aaa3b38>,
#  'clarity': <gensim.models.keyedvectors.Vocab at 0x14aaa3b70>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x14aaa3ba8>,
#  ...}

# %%
word = 'trump'
print(f"Word {word} is represented by {len(w2v_model.wv[word])}-dim vector:")
w2v_model.wv[word]
# Out:
# Word trump is represented by 150-dim vector:
# array([-3.0021594e+00, -1.6013217e+00, -1.3477046e+00,  1.8107045e+00,
#         1.0545655e+00,  2.8576498e+00,  3.1857543e+00, -1.5512133e-01,
#         1.0026896e+00, -2.7203097e+00, -2.6428261e+00,  2.0584211e+00,
#         7.5834483e-01, -8.0337667e-01,  2.7588370e+00,  2.2655666e+00,
#         1.4655324e+00, -1.8966476e+00,  6.8301016e-01,  4.4246539e-02,
#        -3.1087118e-01,  3.5403550e+00, -5.3326893e-01, -1.7692728e+00,
#         5.1000398e-01,  1.6844894e+00,  7.4914271e-01, -2.8916543e+00,
#        -1.0654932e+00, -5.8375257e-01, -1.1625142e+00, -1.8287467e+00,
#         4.3621227e-01, -3.7072525e+00,  1.7972028e+00,  1.6560841e+00,
#        -3.7426863e+00,  8.4443456e-01,  2.2283988e+00, -3.0649856e-01,
#         2.4297147e+00, -3.0128231e+00, -1.7465433e+00,  3.3772628e+00,
#         1.6061653e+00,  1.0635952e+00, -2.8212173e+00,  1.3719076e-01,
#        -3.1639478e-01,  1.9403396e+00, -2.0502132e-01,  8.6858004e-01,
#        -9.9654227e-01, -4.8301321e-01, -2.6555356e-01,  2.6888206e+00,
#         9.0905303e-01, -5.9877735e-01,  3.2961774e+00,  1.1333561e+00,
#         2.6703260e+00,  1.7878838e+00, -6.7697293e-01, -2.5537217e+00,
#        -2.1632507e+00, -4.7508037e-01, -4.5049310e-01, -5.0382328e+00,
#        -2.2512341e+00,  4.3307996e-01, -1.9586581e+00,  1.5800638e+00,
#         4.0679684e+00, -1.1997242e-01,  2.0244372e+00,  1.4216396e+00,
#         7.9756171e-01, -1.2642528e+00,  7.8323144e-01,  3.4948797e+00,
#        -2.5242856e+00,  9.8975134e-01,  5.4074931e-01,  4.7172108e-01,
#         2.0336587e+00,  7.8595364e-01,  2.5215957e-01, -7.2494435e-01,
#         2.4781322e+00,  9.2691332e-01, -1.8025528e+00, -2.3818319e+00,
#        -2.4911174e-01, -1.5535225e+00,  3.6657710e+00, -6.8825006e-01,
#        -3.6328055e-03,  1.7027229e+00,  6.8155861e-01, -2.9895112e-02,
#        -1.2588103e+00, -2.6606252e+00, -2.9235811e+00,  9.1114706e-01,
#         3.1180153e+00,  3.0662975e+00, -2.3945408e+00, -6.2096876e-01,
#         8.0204016e-01, -1.1861439e+00,  3.7078840e-01, -1.6438892e+00,
#        -2.4994108e-01, -2.2030013e+00, -3.6639125e+00, -4.8569334e-01,
#        -1.9351237e+00,  3.2283700e+00,  2.5965164e+00,  1.3214580e+00,
#        -1.6482547e-01,  1.7960490e+00,  1.8401940e+00,  3.3464851e+00,
#         1.8797868e+00,  8.3806479e-01, -3.3162114e-01,  3.3683753e-01,
#         1.1864558e+00, -1.7277020e+00,  1.7309051e+00,  5.9592742e-01,
#         1.6912993e+00,  1.3417380e+00, -1.9881312e+00,  6.3391824e+00,
#        -2.8367278e-01,  1.5818720e+00,  1.9992813e+00, -2.2533849e-01,
#        -6.5665064e+00,  8.7460941e-01, -5.2843034e-01, -1.8162276e+00,
#         2.6651406e-01,  3.9606571e+00, -3.5063000e+00,  5.4800382e+00,
#         4.8427076e+00,  4.0712938e+00], dtype=float32)

# %%
# TSNE representation of N words
N = 1000
wanted_vocab = random.sample(list(w2v_model.wv.vocab), N)
X = w2v_model[wanted_vocab] # X is an array of word vectors, each vector containing 150 tokens
tsne_model = TSNE(perplexity=40, n_components=2, init="pca", n_iter=5000, random_state=23)
Y = tsne_model.fit_transform(X)
# Out:
# /Users/viktor.sohajek/mg_tech_breaks/word2vec/venv_word2vec/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# Plot
trace = go.Scatter(
    x = Y[:,0],
    y = Y[:,1],
    text = list(wanted_vocab),
    mode='text'
)

data = [trace]

# Plot and embed in ipython notebook!
iplot(data, filename='basic-scatter')
# Out:
# <div id="0597f713-a66a-4cd0-87cf-6952aced0098" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("0597f713-a66a-4cd0-87cf-6952aced0098")) {
#     Plotly.newPlot("0597f713-a66a-4cd0-87cf-6952aced0098", [{"mode": "text", "text": ["bunk", "certainty", "arse", "morally", "filmmakers", "markup", "adopting", "serial", "measuring", "tea", "ieee", "hrc", "allusions", "limit", "websites", "translators", "felix", "routines", "live", "factorial", "cues", "october", "iimjobs", "providing", "remain", "redshift", "boomer", "byte", "timing", "aeroplane", "coasters", "bets", "nagging", "conversational", "tragedy", "cured", "message", "ahalya", "bluray", "yell", "kingroot", "affect", "sweat", "dongles", "emptied", "cottage", "cpc", "russia", "daydreaming", "dinar", "ues", "priming", "much", "clicking", "epub", "thailand", "redundancy", "casting", "uncomplicated", "ind", "poo", "sizeof", "oceanic", "races", "ea", "attenuation", "glorified", "bengal", "nitride", "zh\u00ec", "fewer", "novato", "cma", "ncat", "bows", "lynn", "integral", "paramedics", "graviton", "surah", "burr", "socrates", "highway", "cancels", "enacted", "standstill", "mathbf", "tattooed", "expressing", "plurality", "sabha", "admitting", "ultimately", "awful", "din", "ouster", "blackstone", "construction", "tuned", "kanhangad", "promiscuity", "factoring", "cultures", "editorial", "shortcomings", "aiesec", "surfaces", "stereotype", "vampire", "passes", "scanning", "platonic", "monjee", "washing", "fasciitis", "individualism", "hatake", "itchiness", "akamai", "carrots", "eruptive", "prayers", "junit", "nipple", "hooker", "shivsmarak", "protestors", "remarks", "doubled", "relapse", "marries", "orchestra", "author", "manning", "kaggle", "preprocessor", "hosni", "cpap", "advocate", "tc", "chromium", "insertion", "bail", "crappy", "sardesai", "modis", "nigger", "suburb", "terms", "catagory", "budgies", "inductance", "f\u00fcssen", "azhar", "dint", "jenner", "consist", "turned", "fanatics", "bald", "musicians", "conceal", "jatin", "transgender", "contributes", "iq", "hybris", "rallies", "wise", "messianic", "convenient", "prem", "nanotechnology", "stalking", "trivago", "correctness", "buffer", "colbert", "tarantino", "administer", "freeze", "dominar", "evaporate", "importer", "de", "actionscript", "bbc", "discussing", "shortening", "noc", "jojoba", "largest", "factories", "attaching", "thinning", "powerbank", "jellyfish", "demanded", "glacier", "impulsiveness", "stay", "baccalaureate", "ramsey", "lotr", "positives", "motion", "walkie", "fertilization", "protector", "resistivity", "superfluid", "ghosts", "clarification", "peppermint", "obi", "sees", "zest", "racer", "inks", "jewellery", "ideology", "accredited", "amrita", "sst", "sharif", "deaths", "daiict", "sharks", "slider", "affiliate", "clubbing", "nyc", "lyrics", "embedded", "loosing", "lords", "pertaining", "beheaded", "lynxes", "ppc", "bloodborne", "uc", "hoodie", "chairperson", "hobbes", "denver", "mrs", "pizza", "onenote", "cept", "halo", "passer", "sheryl", "grandchildren", "reaction", "lenin", "utilise", "hottest", "subtitled", "xiaoping", "payroll", "ritalin", "infertile", "costliest", "specks", "derivative", "bathroom", "quentin", "emitting", "healthiest", "listening", "gravitons", "bx", "hospitality", "veet", "ankara", "manson", "recovering", "nucleophile", "designation", "sunlight", "mercury", "neutered", "hrd", "doubleclick", "residue", "shorter", "banging", "likewise", "single", "galvanometer", "logical", "admixture", "desk", "publication", "yiannopoulos", "pairs", "keylogger", "deserts", "risks", "escalate", "arms", "disbarred", "midget", "armies", "belize", "debug", "cuomo", "saxon", "wedge", "arthur", "downsides", "solid", "sought", "gendry", "itt", "learners", "spoils", "raisin", "egg", "exaggerated", "measures", "mcdowell", "guatemala", "mla", "threat", "tantric", "determinants", "move", "unique", "teresa", "tighter", "intex", "allbestlist", "scissors", "slow", "massively", "hydrochloric", "semitic", "we", "ducks", "fluid", "manual", "marketo", "promotional", "mms", "writings", "chromebooks", "axiomatic", "cockpit", "birthdays", "truths", "norvig", "gaa ...

# %% [markdown]
# ## Using the model

# %%
# Find similar word 1
words1 = ['trump']
w2v_model.wv.most_similar(positive=words1, topn=10)
# Out:
# [('trumps', 0.7408903241157532),
#  ('knuth', 0.6836468577384949),
#  ('hoffman', 0.6373307704925537),
#  ('hillary', 0.6026067733764648),
#  ('obama', 0.5921074151992798),
#  ('bernie', 0.5784475803375244),
#  ('president', 0.5665757656097412),
#  ('democrats', 0.5629357099533081),
#  ('election', 0.5411714315414429),
#  ('presidential', 0.5351323485374451)]

# %%
# Find similar word 2
words1 = ['panda', 'rabbit', 'dog']
w2v_model.wv.most_similar(positive=words1, topn=10)
# Out:
# [('hamster', 0.78056800365448),
#  ('shrimp', 0.7587584853172302),
#  ('chow', 0.7555397748947144),
#  ('tuna', 0.7444003820419312),
#  ('canned', 0.7407806515693665),
#  ('snake', 0.734947144985199),
#  ('fleas', 0.7347173690795898),
#  ('leopard', 0.7345868349075317),
#  ('rat', 0.7278550863265991),
#  ('pug', 0.7276909947395325)]

# %%
# Find similar word 4
words1 = ['husband', 'man']
words2 = ['woman']
w2v_model.wv.most_similar(positive=words1, negative=words2, topn=10)
# Out:
# [('wife', 0.7653980851173401),
#  ('son', 0.6974135637283325),
#  ('daughter', 0.6875126361846924),
#  ('mother', 0.6809148788452148),
#  ('brother', 0.6784870624542236),
#  ('father', 0.6765068769454956),
#  ('dad', 0.6480885148048401),
#  ('sister', 0.6466807126998901),
#  ('mom', 0.6303774118423462),
#  ('boyfriend', 0.6156502366065979)]

# %%
# Find similar word 5
words1 = ['president', 'trump']
words2 = ['strength']
w2v_model.wv.most_similar(positive=words1, negative=words2, topn=10)

# %%
# Find similar word 4
words1 = ['programming','beginner']
words2 = []
w2v_model.wv.most_similar(positive=words1, negative=words2, topn=10)

# %%
# What should not be there? 1
w2v_model.wv.doesnt_match(['tesla', 'bmw', 'superman', 'mercedes'])

# %%
# What should not be there? 2
w2v_model.wv.doesnt_match(['trump', 'president', 'wall', 'business'])

# %%
# What should not be there? 3
w2v_model.wv.doesnt_match(['weed', 'beer', 'herion', 'cocain'])

# %% [markdown]
# ## Sources
# [Wiki](https://en.wikipedia.org/wiki/Word2vec)
#
# [Good Article 1](https://blog.acolyer.org/2016/04/21/the-amazing-power-of-word-vectors/)
#
# [Good Article 1](http://kavita-ganesan.com/gensim-word2vec-tutorial-starter-code/#.XJfruC1_HUo)
#
# [Tensor Flow Article](https://www.tensorflow.org/tutorials/representation/word2vec)
